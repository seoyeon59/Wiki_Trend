# %%
# 라이브러리 할당
import pandas as pd
import numpy as np

# %%
# 데이터셋 불러오기
df = pd.read_csv('wiki_trend.csv')

# df 값 보기
print(f"df.shape : {df.shape}")
print("\n[df.info 확인]")
df.info()
print(f"\n[df.head 확인] \n {df.head()}")
# Out:
# df.shape : (3226, 17)
#
# [df.info 확인]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3226 non-null   float64
#  1   type            3226 non-null   object
#  2   namespace       3226 non-null   int64
#  3   title           3226 non-null   object
#  4   comment         2842 non-null   object
#  5   timestamp       3226 non-null   object
#  6   user            3226 non-null   object
#  7   bot             3226 non-null   bool
#  8   minor           3226 non-null   object
#  9   revision        3226 non-null   object
#  10  wiki            3226 non-null   object
#  11  parsedcomment   2842 non-null   object
#  12  length_old      3226 non-null   int64
#  13  length_new      3226 non-null   int64
#  14  len_diff        3226 non-null   int64
#  15  time_delta      1084 non-null   object
#  16  time_delta_sec  3226 non-null   float64
# dtypes: bool(1), float64(2), int64(4), object(10)
# memory usage: 406.5+ KB
#
# [df.head 확인]
#               id  type  namespace                                title  \
# 0  2.006463e+09  edit          0                                    0
# 1  2.006464e+09  edit          0                       112th Grey Cup
# 2  2.006464e+09  edit          0       13th Illinois General Assembly
# 3  2.006464e+09  edit          0  13th Parliament of British Columbia
# 4  2.006464e+09  edit          0                13th Tripura Assembly
#
#                                              comment            timestamp  \
# 0         /* India */ Fix unnecessary capitalization  2026-03-16 16:20:08
# 1  v2.05 - Repaired 1 link to disambiguation page...  2026-03-16 16:22:13
# 2  /* House */ Typo fixing, replaced: politican →...  2026-03-16 16:23:28
# 3  /* top */ Typo fixing, replaced: polititian → ...  2026-03-16 16:23:42
# 4              /* Members of Legislative Assembly */  2026-03-16 16:23:39
#
#               user    bot minor                                revision  \
# 0  Finalthunder526  False   1.0  {'old': 1343815868, 'new': 1343821620}
# 1       Tassedethe  False   1.0  {'old': 1341789728, 'new': 1343821947}
# 2  John of Reading  False   1.0  {'old': 1331192330, 'new': 1343822102}
# 3  John of Reading  False   1.0  {'old': 1327982618, 'new': 1343822137}
# 4   ~2026-13797-11  False   0.0  {'old': 1343820321, 'new': 1343822125}
#
#      wiki                                      parsedcomment  length_old  \
# 0  enwiki  <span class="autocomment"><a href="/wiki/0#Ind...       77336
# 1  enwiki  v2.05 - Repaired 1 link to disambiguation page...       52533
# 2  enwiki  <span class="autocomment"><a href="/wiki/13th_...       24570
# 3  enwiki  <span class="autocomment"><a href="/wiki/13th_...       12690
# 4  enwiki  <span class="autocomment"><a href="/wiki/13th_...       19183
#
#    length_new  len_diff time_delta  time_delta_sec
# 0       77336         0        NaN             0.0
# 1       52566        33        NaN             0.0
# 2       24571         1        NaN             0.0
# 3       12690         0        NaN             0.0
# 4       19427       244        NaN             0.0

# %%
# 컬럼명 확인
df.columns
# Out:
# Index(['id', 'type', 'namespace', 'title', 'comment', 'timestamp', 'user',
#        'bot', 'minor', 'revision', 'wiki', 'parsedcomment', 'length_old',
#        'length_new', 'len_diff', 'time_delta', 'time_delta_sec'],
#       dtype='object')

# %%
# 'is_first_post' 컬럼 생성
df['is_first_post'] = df['time_delta'].isnull()

# %%
df
# Out:
#                 id  type  namespace                                title  \
# 0     2.006463e+09  edit          0                                    0
# 1     2.006464e+09  edit          0                       112th Grey Cup
# 2     2.006464e+09  edit          0       13th Illinois General Assembly
# 3     2.006464e+09  edit          0  13th Parliament of British Columbia
# 4     2.006464e+09  edit          0                13th Tripura Assembly
# ...            ...   ...        ...                                  ...
# 3221  2.006464e+09  edit          0                           Zee Asadel
# 3222  2.006463e+09  edit          0                     Zenande Mfenyana
# 3223  2.006464e+09  edit          0                        Zhang Dingfan
# 3224  2.006466e+09  edit          0        Étienne-Charles de Damas-Crux
# 3225  2.006462e+09  edit          0                          Škoda Works
#
#                                                 comment            timestamp  \
# 0            /* India */ Fix unnecessary capitalization  2026-03-16 16:20:08
# 1     v2.05 - Repaired 1 link to disambiguation page...  2026-03-16 16:22:13
# 2     /* House */ Typo fixing, replaced: politican →...  2026-03-16 16:23:28
# 3     /* top */ Typo fixing, replaced: polititian → ...  2026-03-16 16:23:42
# 4                 /* Members of Legislative Assembly */  2026-03-16 16:23:39
# ...                                                 ...                  ...
# 3221                                         /* Film */  2026-03-16 16:21:40
# 3222                                  Expanding article  2026-03-16 16:19:12
# 3223        Dating maintenance tags: {{More citations}}  2026-03-16 16:25:35
# 3224  Dating maintenance tags: {{Cn}} {{More citatio...  2026-03-16 16:31:03
# 3225                                            en dash  2026-03-16 16:16:54
#
#                  user    bot minor                                revision  \
# 0     Finalthunder526  False   1.0  {'old': 1343815868, 'new': 1343821620}
# 1          Tassedethe  False   1.0  {'old': 1341789728, 'new': 1343821947}
# 2     John of Reading  False   1.0  {'old': 1331192330, 'new': 1343822102}
# 3     John of Reading  False   1.0  {'old': 1327982618, 'new': 1343822137}
# 4      ~2026-13797-11  False   0.0  {'old': 1343820321, 'new': 1343822125}
# ...               ...    ...   ...                                     ...
# 3221   ~2026-16376-68  False   0.0  {'old': 1343815123, 'new': 1343821861}
# 3222     Colanao Khod  False   0.0  {'old': 1342308773, 'new': 1343821506}
# 3223        AnomieBOT   True   1.0  {'old': 1343819684, 'new': 1343822387}
# 3224        AnomieBOT   True   1.0  {'old': 1343820311, 'new': 1343823109}
# 3225      Archon 2488  False   1.0  {'old': 1342123977, 'new': 1343821189}
#
#         wiki                                      parsedcomment  length_old  \
# 0     enwiki  <span class="autocomment"><a href="/wiki/0#Ind...       77336
# 1     enwiki  v2.05 - Repaired 1 link to disambiguation page...       52533
# 2     enwiki  <span class="autocomment"><a href="/wiki/13th_...       24570
# 3     enwiki  <span class="autocomment"><a href="/wiki/13th_...       12690
# 4     enwiki  <span class="autocomment"><a href="/wiki/13th_...       19183
# ...      ...                                                ...         ...
# 3221  enwiki  <span class="autocomment"><a href="/wiki/Zee_A...       19958
# 3222  enwiki                                  Expanding article        4988
# 3223  enwiki        Dating maintenance tags: {{More citations}}        5915
# 3224  enwiki  Dating maintenance tags: {{Cn}} {{More citatio...        8310
# 3225  enwiki                                            en dash       24797
#
#       length_new  len_diff time_delta  time_delta_sec  is_first_post
# 0          77336         0        NaN             0.0           True
# 1          52566        33        NaN             0.0           True
# 2          24571         1        NaN             0.0           True
# 3          12690         0        NaN             0.0           True
# 4          19427       244        NaN             0.0           True
# ...          ...       ...        ...             ...            ...
# 3221       20203       245        NaN             0.0           True
# 3222        5470       482        NaN             0.0           True
# 3223        5931        16        NaN             0.0           True
# 3224        8342        32        NaN             0.0           True
# 3225       24806         9        NaN             0.0           True
#
# [3226 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3226 non-null   float64
#  1   type            3226 non-null   object
#  2   namespace       3226 non-null   int64
#  3   title           3226 non-null   object
#  4   comment         2842 non-null   object
#  5   timestamp       3226 non-null   object
#  6   user            3226 non-null   object
#  7   bot             3226 non-null   bool
#  8   minor           3226 non-null   object
#  9   revision        3226 non-null   object
#  10  wiki            3226 non-null   object
#  11  parsedcomment   2842 non-null   object
#  12  length_old      3226 non-null   int64
#  13  length_new      3226 non-null   int64
#  14  len_diff        3226 non-null   int64
#  15  time_delta      1084 non-null   object
#  16  time_delta_sec  3226 non-null   float64
#  17  is_first_post   3226 non-null   bool
# dtypes: bool(2), float64(2), int64(4), object(10)
# memory usage: 409.7+ KB

# %%
# type 컬럼 내용 확인
print(df['type'].value_counts())
# Out:
# type
# edit          1983
# categorize    1046
# log            122
# new             75
# Name: count, dtype: int64

# %% [markdown]
# -> 이 컬럼은 원핫인코딩 해야할듯?

# %%
# namespace nan값 처리 
# 0(Main): 본문, 1(Talk): 토론 등 위키의 공간 구분
# nan은 0으로 채우기
df['namespace'] = df['namespace'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3226 non-null   float64
#  1   type            3226 non-null   object
#  2   namespace       3226 non-null   int64
#  3   title           3226 non-null   object
#  4   comment         2842 non-null   object
#  5   timestamp       3226 non-null   object
#  6   user            3226 non-null   object
#  7   bot             3226 non-null   bool
#  8   minor           3226 non-null   object
#  9   revision        3226 non-null   object
#  10  wiki            3226 non-null   object
#  11  parsedcomment   2842 non-null   object
#  12  length_old      3226 non-null   int64
#  13  length_new      3226 non-null   int64
#  14  len_diff        3226 non-null   int64
#  15  time_delta      1084 non-null   object
#  16  time_delta_sec  3226 non-null   float64
#  17  is_first_post   3226 non-null   bool
# dtypes: bool(2), float64(2), int64(4), object(10)
# memory usage: 409.7+ KB

# %%
# parsedcomment Nan값 처리
# 'No comment'로 채우기
df['parsedcomment'] = df['parsedcomment'].fillna('No comment')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3226 non-null   float64
#  1   type            3226 non-null   object
#  2   namespace       3226 non-null   int64
#  3   title           3226 non-null   object
#  4   comment         2842 non-null   object
#  5   timestamp       3226 non-null   object
#  6   user            3226 non-null   object
#  7   bot             3226 non-null   bool
#  8   minor           3226 non-null   object
#  9   revision        3226 non-null   object
#  10  wiki            3226 non-null   object
#  11  parsedcomment   3226 non-null   object
#  12  length_old      3226 non-null   int64
#  13  length_new      3226 non-null   int64
#  14  len_diff        3226 non-null   int64
#  15  time_delta      1084 non-null   object
#  16  time_delta_sec  3226 non-null   float64
#  17  is_first_post   3226 non-null   bool
# dtypes: bool(2), float64(2), int64(4), object(10)
# memory usage: 409.7+ KB

# %%
# 컬럼별로 전처리 시작
df = pd.get_dummies(df, columns=['type'], drop_first=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3226 non-null   float64
#  1   namespace       3226 non-null   int64
#  2   title           3226 non-null   object
#  3   comment         2842 non-null   object
#  4   timestamp       3226 non-null   object
#  5   user            3226 non-null   object
#  6   bot             3226 non-null   bool
#  7   minor           3226 non-null   object
#  8   revision        3226 non-null   object
#  9   wiki            3226 non-null   object
#  10  parsedcomment   3226 non-null   object
#  11  length_old      3226 non-null   int64
#  12  length_new      3226 non-null   int64
#  13  len_diff        3226 non-null   int64
#  14  time_delta      1084 non-null   object
#  15  time_delta_sec  3226 non-null   float64
#  16  is_first_post   3226 non-null   bool
#  17  type_edit       3226 non-null   bool
#  18  type_log        3226 non-null   bool
#  19  type_new        3226 non-null   bool
# dtypes: bool(5), float64(2), int64(4), object(9)
# memory usage: 393.9+ KB

# %%
# namespce 컬럼 확인
print(df['namespace'].value_counts())
# Out:
# namespace
# 0      1448
# 14     1065
# 2       241
# 3       128
# 4        98
# 1        91
# 118      70
# 10       51
# 11       17
# 119       5
# 6         4
# 5         3
# 15        2
# 101       2
# 13        1
# Name: count, dtype: int64

# %%
# 데이터가 적은 namespace를 'Others'로 묶어 모델 단순화 진행
# 빈도가 낮은 항목(50개 미만) 항목을 모두 한 그룹으로 통합
def group_minor_ns(ns):
    # 상위 주요 namespace만 유지 (0: 본문, 14: 카테고리, 2: 사용자, 3: 사용자토론 등)
    if ns in [0, 14, 2, 3, 4, 1]:
        return str(ns)
    else:
        return 'others'

df['ns_grouped'] = df['namespace'].apply(group_minor_ns)


# 정재된 컬럼으로 원핫인코딩 수행
df = pd.get_dummies(df, columns=['ns_grouped'], drop_first=True)

# %%
df = df.drop(columns=['namespace'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3226 non-null   float64
#  1   title              3226 non-null   object
#  2   comment            2842 non-null   object
#  3   timestamp          3226 non-null   object
#  4   user               3226 non-null   object
#  5   bot                3226 non-null   bool
#  6   minor              3226 non-null   object
#  7   revision           3226 non-null   object
#  8   wiki               3226 non-null   object
#  9   parsedcomment      3226 non-null   object
#  10  length_old         3226 non-null   int64
#  11  length_new         3226 non-null   int64
#  12  len_diff           3226 non-null   int64
#  13  time_delta         1084 non-null   object
#  14  time_delta_sec     3226 non-null   float64
#  15  is_first_post      3226 non-null   bool
#  16  type_edit          3226 non-null   bool
#  17  type_log           3226 non-null   bool
#  18  type_new           3226 non-null   bool
#  19  ns_grouped_1       3226 non-null   bool
#  20  ns_grouped_14      3226 non-null   bool
#  21  ns_grouped_2       3226 non-null   bool
#  22  ns_grouped_3       3226 non-null   bool
#  23  ns_grouped_4       3226 non-null   bool
#  24  ns_grouped_others  3226 non-null   bool
# dtypes: bool(11), float64(2), int64(3), object(9)
# memory usage: 387.6+ KB

# %%
# title 파생 변수 만들기
# 제목 글자 수 추출
df['title_len'] = df['title'].str.len()

# 타이틀에 특정 키워드 포함 여부 이진화
# 어떤 키워드를 넣을지 논의 후 추가 작성

# title 컬럼 삭제
# df = df.drop(columns=['title'])

# %%
# comment 컬럼 확인
print(df['comment'].value_counts())
# Out:
# comment
# sources                                                 70
# Added {{[[Template:Unreferenced|Unreferenced]]}} tag    42
# update - match played 14 March 2026                     22
# [[:Dimitris Chatsidis]] added to category               18
# expand name for clarity                                 16
#                                                         ..
# Added                                                    1
# /* United States */                                      1
# /* Media rights */                                       1
# /* Recovery efforts */                                   1
# en dash                                                  1
# Name: count, Length: 1745, dtype: int64

# %%
# comment(편집 용약) 컬럼 수치화
# 결측치 처리 (앞서 했던 대로 'No comment'로 통일)
df['comment'] = df['comment'].fillna('No comment').astype(str)


# 편집의 성격을 나타내는 핵심 키워드 추출 (이진 변수 생성
# 'revert'가 포함되면 편집 갈등 가능성 높으므로 1, 아니면 0
df['is_revert'] = df['comment'].str.contains('revert|rvv|undo', case=False).astype(int)

# 'update'나 'added'가 포함되면 정보 추가 가능성이 높음
df['is_update'] = df['comment'].str.contains('update|added|expand', case=False).astype(int)

# 'typo'나 'fix'가 포함되면 사소한 수정일 가능성이 높음
df['is_minor_fix'] = df['comment'].str.contains('typo|fix|correction|clean up', case=False).astype(int)


# 코멘트 글자 수 추출
df['comment_len'] = df['comment'].str.len()


# comment 컬럼 삭제
df = df.drop(columns=['comment'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3226 non-null   float64
#  1   title              3226 non-null   object
#  2   timestamp          3226 non-null   object
#  3   user               3226 non-null   object
#  4   bot                3226 non-null   bool
#  5   minor              3226 non-null   object
#  6   revision           3226 non-null   object
#  7   wiki               3226 non-null   object
#  8   parsedcomment      3226 non-null   object
#  9   length_old         3226 non-null   int64
#  10  length_new         3226 non-null   int64
#  11  len_diff           3226 non-null   int64
#  12  time_delta         1084 non-null   object
#  13  time_delta_sec     3226 non-null   float64
#  14  is_first_post      3226 non-null   bool
#  15  type_edit          3226 non-null   bool
#  16  type_log           3226 non-null   bool
#  17  type_new           3226 non-null   bool
#  18  ns_grouped_1       3226 non-null   bool
#  19  ns_grouped_14      3226 non-null   bool
#  20  ns_grouped_2       3226 non-null   bool
#  21  ns_grouped_3       3226 non-null   bool
#  22  ns_grouped_4       3226 non-null   bool
#  23  ns_grouped_others  3226 non-null   bool
#  24  title_len          3226 non-null   int64
#  25  is_revert          3226 non-null   int32
#  26  is_update          3226 non-null   int32
#  27  is_minor_fix       3226 non-null   int32
#  28  comment_len        3226 non-null   int64
# dtypes: bool(11), float64(2), int32(3), int64(5), object(8)
# memory usage: 450.6+ KB

# %%
# timestamp 컬럼 삭제
df = df.drop(columns=['timestamp'])

# %%
# user 컬럼 확인
print(df['user'].value_counts())
# Out:
# user
# Lollipoplollipoplollipop    172
# ForsythiaJo                  93
# BlackJack                    85
# Tarkowski                    65
# Tassedethe                   51
#                            ...
# Lonniemitchell22              1
# TauErDaWritter                1
# Loopy30                       1
# Crystal Drawers               1
# Archon 2488                   1
# Name: count, Length: 800, dtype: int64

# %%
# user 컬럼의 수치 지표화
# 사용자별 편집 빈도 계산 (Frequency Encoding)
user_counts = df['user'].value_counts().to_dict()
df['user_activity_score'] = df['user'].map(user_counts)

# 헤비 에디터 여부 (상위 10% 수준인 50회 이상 편집 기준)
df['is_pro_editor'] = (df['user_activity_score'] >= 50).astype(int)

# user 컬럼 삭제
df = df.drop(columns=['user'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3226 non-null   float64
#  1   title                3226 non-null   object
#  2   bot                  3226 non-null   bool
#  3   minor                3226 non-null   object
#  4   revision             3226 non-null   object
#  5   wiki                 3226 non-null   object
#  6   parsedcomment        3226 non-null   object
#  7   length_old           3226 non-null   int64
#  8   length_new           3226 non-null   int64
#  9   len_diff             3226 non-null   int64
#  10  time_delta           1084 non-null   object
#  11  time_delta_sec       3226 non-null   float64
#  12  is_first_post        3226 non-null   bool
#  13  type_edit            3226 non-null   bool
#  14  type_log             3226 non-null   bool
#  15  type_new             3226 non-null   bool
#  16  ns_grouped_1         3226 non-null   bool
#  17  ns_grouped_14        3226 non-null   bool
#  18  ns_grouped_2         3226 non-null   bool
#  19  ns_grouped_3         3226 non-null   bool
#  20  ns_grouped_4         3226 non-null   bool
#  21  ns_grouped_others    3226 non-null   bool
#  22  title_len            3226 non-null   int64
#  23  is_revert            3226 non-null   int32
#  24  is_update            3226 non-null   int32
#  25  is_minor_fix         3226 non-null   int32
#  26  comment_len          3226 non-null   int64
#  27  user_activity_score  3226 non-null   int64
#  28  is_pro_editor        3226 non-null   int32
# dtypes: bool(11), float64(2), int32(4), int64(6), object(6)
# memory usage: 438.0+ KB

# %%
# minor 컬럼 확인
print(df['minor'].value_counts())
# Out:
# minor
# 0.0      1748
# False    1168
# 1.0       310
# Name: count, dtype: int64

# %%
# 0.0, False 모두 0으로 처리, 1.0을 1로 처리
df['minor'] = df['minor'].replace({'False': 0, 'True': 1}).astype(float).astype(int)

# %%
print(df['minor'].value_counts())
# Out:
# minor
# 0    2916
# 1     310
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3226 non-null   float64
#  1   title                3226 non-null   object
#  2   bot                  3226 non-null   bool
#  3   minor                3226 non-null   int32
#  4   revision             3226 non-null   object
#  5   wiki                 3226 non-null   object
#  6   parsedcomment        3226 non-null   object
#  7   length_old           3226 non-null   int64
#  8   length_new           3226 non-null   int64
#  9   len_diff             3226 non-null   int64
#  10  time_delta           1084 non-null   object
#  11  time_delta_sec       3226 non-null   float64
#  12  is_first_post        3226 non-null   bool
#  13  type_edit            3226 non-null   bool
#  14  type_log             3226 non-null   bool
#  15  type_new             3226 non-null   bool
#  16  ns_grouped_1         3226 non-null   bool
#  17  ns_grouped_14        3226 non-null   bool
#  18  ns_grouped_2         3226 non-null   bool
#  19  ns_grouped_3         3226 non-null   bool
#  20  ns_grouped_4         3226 non-null   bool
#  21  ns_grouped_others    3226 non-null   bool
#  22  title_len            3226 non-null   int64
#  23  is_revert            3226 non-null   int32
#  24  is_update            3226 non-null   int32
#  25  is_minor_fix         3226 non-null   int32
#  26  comment_len          3226 non-null   int64
#  27  user_activity_score  3226 non-null   int64
#  28  is_pro_editor        3226 non-null   int32
# dtypes: bool(11), float64(2), int32(5), int64(6), object(5)
# memory usage: 425.4+ KB

# %%
# revision 컬럼은 현재 수정 버전의 고유 버전
# 성숙도와 수정 이력을 알려줌
# 낮은 숫자 : 최근에 만들어졌거나 수정이 거의 없었던 초기 단계의 문서일 확률이 높음
# 높은 숫자 : 수많은 사람의 손을 거쳐 내영이 정교해지고 검증된, 성숙한 문서임을 의미

# revision 컬럼 내용 확인
print(df['revision'].value_counts())
# Out:
# revision
# 0                                         1168
# {'old': 1343815868, 'new': 1343821620}       1
# {'old': 1343576653, 'new': 1343821196}       1
# {'old': 1343820964, 'new': 1343821545}       1
# {'new': 1343821367}                          1
#                                           ...
# {'old': 1343590511, 'new': 1343822057}       1
# {'old': 1342553045, 'new': 1343822096}       1
# {'old': 1343823186, 'new': 1343823297}       1
# {'old': 1341306804, 'new': 1343823186}       1
# {'old': 1342123977, 'new': 1343821189}       1
# Name: count, Length: 2059, dtype: int64

# %%
# old와 new 값 추출
df[['rev_old', 'rev_new']] = df['revision'].apply(
    lambda x: pd.Series([x.get('old', 0), x.get('new', 0)]) if isinstance(x, dict) else pd.Series([0, 0])
)

# 딕셔너리가 아닌 숫자로 들어온 경우
df.loc[df['rev_new'] == 0, 'rev_new'] = pd.to_numeric(df['revision'], errors='coerce').fillna(0)

# 타입 정수형으로 통일
df['rev_old'] = df['rev_old'].astype(int)
df['rev_new'] = df['rev_new'].astype(int)

# 버전 차이 계산
df['rev_diff'] = df['rev_new'] - df['rev_old']

df = df.drop(columns=['revision'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3226 non-null   float64
#  1   title                3226 non-null   object
#  2   bot                  3226 non-null   bool
#  3   minor                3226 non-null   int32
#  4   wiki                 3226 non-null   object
#  5   parsedcomment        3226 non-null   object
#  6   length_old           3226 non-null   int64
#  7   length_new           3226 non-null   int64
#  8   len_diff             3226 non-null   int64
#  9   time_delta           1084 non-null   object
#  10  time_delta_sec       3226 non-null   float64
#  11  is_first_post        3226 non-null   bool
#  12  type_edit            3226 non-null   bool
#  13  type_log             3226 non-null   bool
#  14  type_new             3226 non-null   bool
#  15  ns_grouped_1         3226 non-null   bool
#  16  ns_grouped_14        3226 non-null   bool
#  17  ns_grouped_2         3226 non-null   bool
#  18  ns_grouped_3         3226 non-null   bool
#  19  ns_grouped_4         3226 non-null   bool
#  20  ns_grouped_others    3226 non-null   bool
#  21  title_len            3226 non-null   int64
#  22  is_revert            3226 non-null   int32
#  23  is_update            3226 non-null   int32
#  24  is_minor_fix         3226 non-null   int32
#  25  comment_len          3226 non-null   int64
#  26  user_activity_score  3226 non-null   int64
#  27  is_pro_editor        3226 non-null   int32
#  28  rev_old              3226 non-null   int32
#  29  rev_new              3226 non-null   int32
#  30  rev_diff             3226 non-null   int32
# dtypes: bool(11), float64(2), int32(8), int64(6), object(4)
# memory usage: 438.0+ KB

# %%
print(df['wiki'].value_counts())
# Out:
# wiki
# enwiki    3226
# Name: count, dtype: int64

# %%
# 컬럼 삭제
df = df.drop(columns=['wiki'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3226 non-null   float64
#  1   title                3226 non-null   object
#  2   bot                  3226 non-null   bool
#  3   minor                3226 non-null   int32
#  4   parsedcomment        3226 non-null   object
#  5   length_old           3226 non-null   int64
#  6   length_new           3226 non-null   int64
#  7   len_diff             3226 non-null   int64
#  8   time_delta           1084 non-null   object
#  9   time_delta_sec       3226 non-null   float64
#  10  is_first_post        3226 non-null   bool
#  11  type_edit            3226 non-null   bool
#  12  type_log             3226 non-null   bool
#  13  type_new             3226 non-null   bool
#  14  ns_grouped_1         3226 non-null   bool
#  15  ns_grouped_14        3226 non-null   bool
#  16  ns_grouped_2         3226 non-null   bool
#  17  ns_grouped_3         3226 non-null   bool
#  18  ns_grouped_4         3226 non-null   bool
#  19  ns_grouped_others    3226 non-null   bool
#  20  title_len            3226 non-null   int64
#  21  is_revert            3226 non-null   int32
#  22  is_update            3226 non-null   int32
#  23  is_minor_fix         3226 non-null   int32
#  24  comment_len          3226 non-null   int64
#  25  user_activity_score  3226 non-null   int64
#  26  is_pro_editor        3226 non-null   int32
#  27  rev_old              3226 non-null   int32
#  28  rev_new              3226 non-null   int32
#  29  rev_diff             3226 non-null   int32
# dtypes: bool(11), float64(2), int32(8), int64(6), object(3)
# memory usage: 412.8+ KB

# %%
# parsedcomment 컬럼 확인
print(df['parsedcomment'].value_counts())
# Out:
# parsedcomment
# No comment                                                                                                                                                                                                                                                                                                                                                                  384
# sources                                                                                                                                                                                                                                                                                                                                                                      70
# Added {{<a href="/wiki/Template:Unreferenced" title="Template:Unreferenced">Unreferenced</a>}} tag                                                                                                                                                                                                                                                                           42
# update - match played 14 March 2026                                                                                                                                                                                                                                                                                                                                          22
# <a href="/wiki/Dimitris_Chatsidis" title="Dimitris Chatsidis">Dimitris Chatsidis</a> added to category                                                                                                                                                                                                                                                                       18
#                                                                                                                                                                                                                                                                                                                                                                            ...
# <span class="autocomment"><a href="/wiki/Draft:2011_Northwest_Iowa_tornadoes#Recovery_efforts" title="Draft:2011 Northwest Iowa tornadoes">→<bdi dir="ltr">Recovery efforts</bdi></a></span>                                                                                                                                                                                  1
# Adding WikiProject tags (<a href="/wiki/MediaWiki:AFC-add-project-tags.js" title="MediaWiki:AFC-add-project-tags.js">assisted</a>)                                                                                                                                                                                                                                            1
# <a href="/wiki/Wikipedia:CSD#G8" class="mw-redirect" title="Wikipedia:CSD">G8</a>: Talk page of deleted page <a href="/w/index.php?title=Draft:Simone_Scaglia&amp;action=edit&amp;redlink=1" class="new" title="Draft:Simone Scaglia (page does not exist)">Draft:Simone Scaglia</a>                                                                                          1
# <a href="/wiki/Wikipedia:CSD#G8" class="mw-redirect" title="Wikipedia:CSD">G8</a>: <a href="/wiki/Help:Talk_page" class="mw-redirect" title="Help:Talk page">Talk page</a> of deleted page <a href="/w/index.php?title=Draft:Michael_D._Ponce&amp;action=edit&amp;redlink=1" class="new" title="Draft:Michael D. Ponce (page does not exist)">Draft:Michael D. Ponce</a>      1
# en dash                                                                                                                                                                                                                                                                                                                                                                       1
# Name: count, Length: 1828, dtype: int64

# %%
import re

# [전처리] parsedcomment HTML 태그 제거 및 텍스트 정제
def clean_html(raw_html):
    if not isinstance(raw_html, str):
        return "No comment"
    # HTML 태그 제거 (정규표현식 사용)
    clean_text = re.sub(r'<.*?>', '', raw_html)
    # 불필요한 공백 제거
    clean_text = clean_text.strip()
    return clean_text if clean_text else "No comment"

# 태그가 제거된 순수 텍스트 컬럼 생성
df['comment_cleaned'] = df['parsedcomment'].apply(clean_html)


# [추가 피처] 특정 섹션 수정 여부 확인 (autocomment 패턴)
# "/* ... */" 형태는 특정 섹션을 수정했다는 의미이므로 이진 변수화
df['is_section_edit'] = df['parsedcomment'].str.contains('class="autocomment"', na=False).astype(int)

# 정제된 텍스트의 길이 추출
df['comment_clean_len'] = df['comment_cleaned'].str.len()

df = df.drop(columns=(['parsedcomment']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3226 non-null   float64
#  1   title                3226 non-null   object
#  2   bot                  3226 non-null   bool
#  3   minor                3226 non-null   int32
#  4   length_old           3226 non-null   int64
#  5   length_new           3226 non-null   int64
#  6   len_diff             3226 non-null   int64
#  7   time_delta           1084 non-null   object
#  8   time_delta_sec       3226 non-null   float64
#  9   is_first_post        3226 non-null   bool
#  10  type_edit            3226 non-null   bool
#  11  type_log             3226 non-null   bool
#  12  type_new             3226 non-null   bool
#  13  ns_grouped_1         3226 non-null   bool
#  14  ns_grouped_14        3226 non-null   bool
#  15  ns_grouped_2         3226 non-null   bool
#  16  ns_grouped_3         3226 non-null   bool
#  17  ns_grouped_4         3226 non-null   bool
#  18  ns_grouped_others    3226 non-null   bool
#  19  title_len            3226 non-null   int64
#  20  is_revert            3226 non-null   int32
#  21  is_update            3226 non-null   int32
#  22  is_minor_fix         3226 non-null   int32
#  23  comment_len          3226 non-null   int64
#  24  user_activity_score  3226 non-null   int64
#  25  is_pro_editor        3226 non-null   int32
#  26  rev_old              3226 non-null   int32
#  27  rev_new              3226 non-null   int32
#  28  rev_diff             3226 non-null   int32
#  29  comment_cleaned      3226 non-null   object
#  30  is_section_edit      3226 non-null   int32
#  31  comment_clean_len    3226 non-null   int64
# dtypes: bool(11), float64(2), int32(9), int64(7), object(3)
# memory usage: 450.6+ KB

# %%
# time_delta 전처리
# 매우 큰 값으로 채우기(채워두기먄)
df['time_delta'] = df['time_delta'].fillna(9999999)

# %%
# comment_cleaned 컬럼 삭제
df = df.drop(columns=['comment_cleaned'])

# %%
# id 컬럼 삭제
df = df.drop(columns=['id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                3226 non-null   object
#  1   bot                  3226 non-null   bool
#  2   minor                3226 non-null   int32
#  3   length_old           3226 non-null   int64
#  4   length_new           3226 non-null   int64
#  5   len_diff             3226 non-null   int64
#  6   time_delta           3226 non-null   object
#  7   time_delta_sec       3226 non-null   float64
#  8   is_first_post        3226 non-null   bool
#  9   type_edit            3226 non-null   bool
#  10  type_log             3226 non-null   bool
#  11  type_new             3226 non-null   bool
#  12  ns_grouped_1         3226 non-null   bool
#  13  ns_grouped_14        3226 non-null   bool
#  14  ns_grouped_2         3226 non-null   bool
#  15  ns_grouped_3         3226 non-null   bool
#  16  ns_grouped_4         3226 non-null   bool
#  17  ns_grouped_others    3226 non-null   bool
#  18  title_len            3226 non-null   int64
#  19  is_revert            3226 non-null   int32
#  20  is_update            3226 non-null   int32
#  21  is_minor_fix         3226 non-null   int32
#  22  comment_len          3226 non-null   int64
#  23  user_activity_score  3226 non-null   int64
#  24  is_pro_editor        3226 non-null   int32
#  25  rev_old              3226 non-null   int32
#  26  rev_new              3226 non-null   int32
#  27  rev_diff             3226 non-null   int32
#  28  is_section_edit      3226 non-null   int32
#  29  comment_clean_len    3226 non-null   int64
# dtypes: bool(11), float64(1), int32(9), int64(7), object(2)
# memory usage: 400.2+ KB

# %%
df = df.drop(columns=['time_delta', 'rev_old', 'rev_new'])

# %%
# csv 파일 생성
df.to_csv('ml.csv', index=False, encoding='utf-8')
